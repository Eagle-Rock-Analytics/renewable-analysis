# %% [markdown]
# # Climate Drivers of Electricity Demand
#
# This notebook analyzes the relationship between electricity demand and climate variables (temperature, wind, precipitation) across California load zones.
#
# **Key Features:**
# - Regional analysis using load zone shapefiles
# - Flexible demand metrics: SEI (standardized anomaly) or raw peak load
# - Flexible climate metrics: anomalies or raw values
# - Multiple climate variables: temperature, wind speed, precipitation
# - Analysis across models and global warming levels
#
# **Data Sources:**
# - Demand SEI: `compute_demand_sei.ipynb` → `data/SEI/`
# - Demand peak load: `data/demand/DailyPeaks/`
# - Climate data: WRF downscaled via climakitae
# - Regional boundaries: `data/load_zone_shapefiles/allLoadZones.shp`

# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import os
import sys
from pathlib import Path

# Import holoviews for interactive plotting
import holoviews as hv
from holoviews import opts
hv.extension('bokeh')

# Import custom modules
sys.path.append('../../src')
from renewable_data_load import sim_name_dict, get_gwl_crossing_period
from plotting_config import model_colors, gwl_colors, model_markers
from climate_correlation import (
    load_wrf_climate_data_all_simulations,
    extract_simulation_gwl_period,
    compute_regional_climate_average,
    compute_anomalies,
    prepare_correlation_data,
    load_demand_sei,
    load_demand_peak_load
)

# Load matplotlib style sheet
plt.style.use('../../renewable_analysis.mplstyle')

print("Imports successful!")
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a71a4c7a-5f2c-4068-bbb3-097ba839c1ea'>
#   <div id="baeec7a2-0093-4c39-a1de-8062579dc075" data-root-id="a71a4c7a-5f2c-4068-bbb3-097ba839c1ea" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"af30453a-241e-4a8d-a4be-141f68ab3fc5":{"version":"3.8.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"d9daa5fc-3567-45fb-8722-0b3a925b154c","attributes":{"notifications":{"type":"object","name":"Notifications","id":"a91a277d-75eb-41d3-bc48-3a0a62ac3c81"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a71a4c7a-5f2c-4068-bbb3-097ba839c1ea"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"1c99f7f2-f67a-4317-9268-e019392918ea","attributes":{"plot_id":"a71a4c7a-5f2c-4068-bbb3-097ba839c1ea","comm_id":"c2d2707af0164e34b7d4698563151a6a","client_comm_id":"1e19984b22994b9cbe5e89a3228bc5d4"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"af30453a-241e-4a8d-a4be-141f68ab3fc5","roots":{"a71a4c7a-5f2c-4068-bbb3-097ba839c1ea":"baeec7a2-0093-4c39-a1de-8062579dc075"},"root_ids":["a71a4c7a-5f2c-4068-bbb3-097ba839c1ea"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.22.1">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.8.1">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>
# Imports successful!

# %% [markdown]
# ## Configuration
#
# Set analysis parameters including:
# - Climate variables to analyze
# - Demand data type (SEI or raw peak load)
# - Whether to use anomalies or raw values
# - Models and GWL periods
# - Output directory

# %%
# Analysis parameters
simulations = ["ec-earth3", "miroc6", "mpi-esm1-2-hr", "taiesm1"]
gwls = [0.8, 2.0]  # Reference and future warming levels
domain = "d02"

# Climate variables to analyze
climate_variables = {
    "Air Temperature at 2m": "T2m",
    "Relative humidity":"rh"
    # "Mean wind speed at 10m": "Wind10m",
   #"Precipitation (total)": "Precip"
}

# Demand data configuration
demand_data_type = "sei"  # Options: "sei" or "peak_load"
demand_use_anomaly = False  # Only applies if demand_data_type="peak_load"

# Climate data configuration
climate_use_anomaly = True  # Calculate anomalies for climate variables

# Shapefile path
shapefile_path = "../../data/load_zone_shapefiles/allLoadZones.shp"

# Output directory
output_dir = Path("./figures/climate_drivers_of_demand")
output_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Load Demand Data
#
# Load demand data (SEI or raw peak load) for all simulations and regions.

# %%
# Load demand data for all simulations
demand_data = {}

if demand_data_type == "sei":
    print("Loading demand SEI data...")
    for simulation in simulations:
        try:
            demand_data[simulation] = load_demand_sei(
                simulation=simulation,
                data_dir="../../data/SEI",
                domain=domain,
                reference_gwl=0.8
            )
            print(f"  {simulation}: {demand_data[simulation].dims}")
        except FileNotFoundError as e:
            print(f"  Warning: {e}")
else:  # peak_load
    print("Loading raw peak load data...")
    for simulation in simulations:
        try:
            # Load full timeseries (will crop by GWL later)
            demand_data[simulation] = load_demand_peak_load(
                simulation=simulation,
                data_dir="../../data/demand/DailyPeaks"
            )
            print(f"  {simulation}: {demand_data[simulation].dims}")
        except Exception as e:
            print(f"  Warning: Could not load {simulation}: {e}")

print(f"\nLoaded demand data for {len(demand_data)} simulations")

# Show available regions
if demand_data:
    first_sim = list(demand_data.keys())[0]
    print(f"Available regions: {list(demand_data[first_sim].region.values)}")
# Out:
# Loading demand SEI data...
#   ec-earth3: ('region', 'time')
#   miroc6: ('region', 'time')
#   mpi-esm1-2-hr: ('region', 'time')
#   taiesm1: ('region', 'time')
#
# Loaded demand data for 4 simulations
# Available regions: [np.str_('SCE'), np.str_('IID'), np.str_('NCNC'), np.str_('LDWP'), np.str_('WECC-MTN'), np.str_('WECC-SW'), np.str_('PGE'), np.str_('SDGE'), np.str_('WECC-NW')]

# %% [markdown]
# ## Load and Process Climate Data
#
# Load WRF climate variables and aggregate to regional averages using load zone shapefiles.

# %%
# Dictionary to store regional climate data
# Structure: regional_climate[simulation][gwl][climate_var_short_name] = xr.DataArray
regional_climate = {}

# Initialize nested structure
for simulation in simulations:
    regional_climate[simulation] = {}
    for gwl in gwls:
        regional_climate[simulation][gwl] = {}

# Load each climate variable ONCE (efficient!)
print("Loading climate data (one get_data call per variable)...")
print("="*60)

climate_data_cache = {}

for climate_var, var_short in climate_variables.items():
    print(f"\n{climate_var}:")
    print(f"  Loading all simulations... (this may take a minute)")
    
    try:
        # SINGLE call to get_data - returns all 8 simulations
        climate_data_all_sims = load_wrf_climate_data_all_simulations(
            variable=climate_var,
            domain=domain,
            trim_edges=True
        )
        
        climate_data_cache[var_short] = climate_data_all_sims
        
        print(f"  ✓ Loaded: {climate_data_all_sims.dims}")
        print(f"  Available simulations: {list(climate_data_all_sims.simulation.values)}")
        
    except Exception as e:
        print(f"  ✗ Error loading {climate_var}: {e}")
        continue

print("\n" + "="*60)
print(f"Climate data loaded for {len(climate_data_cache)} variables")
print("="*60)
# Out:
# Loading climate data (one get_data call per variable)...
# ============================================================
#
# Air Temperature at 2m:
#   Loading all simulations... (this may take a minute)
# /Users/work/miniconda3/envs/renewables-analysis/lib/python3.12/site-packages/climakitae/core/data_load.py:550: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'time' ('time',) The recommendation is to set join explicitly for this case.
#   all_hist = xr.concat(
# /Users/work/miniconda3/envs/renewables-analysis/lib/python3.12/site-packages/climakitae/core/data_load.py:591: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'time' ('time',) The recommendation is to set join explicitly for this case.
#   one_scenario = xr.concat(
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!! Returned data array is huge. Operations could take 10x to infinity longer than 1GB of data !!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#   ✓ Loaded: ('scenario', 'simulation', 'time', 'y', 'x')
#   Available simulations: [np.str_('WRF_CNRM-ESM2-1_r1i1p1f2'), np.str_('WRF_TaiESM1_r1i1p1f1'), np.str_('WRF_MPI-ESM1-2-HR_r3i1p1f1'), np.str_('WRF_MIROC6_r1i1p1f1'), np.str_('WRF_FGOALS-g3_r1i1p1f1'), np.str_('WRF_CESM2_r11i1p1f1'), np.str_('WRF_EC-Earth3_r1i1p1f1'), np.str_('WRF_EC-Earth3-Veg_r1i1p1f1')]
#
# Relative humidity:
#   Loading all simulations... (this may take a minute)
# /Users/work/miniconda3/envs/renewables-analysis/lib/python3.12/site-packages/climakitae/core/data_load.py:550: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'time' ('time',) The recommendation is to set join explicitly for this case.
#   all_hist = xr.concat(
# /Users/work/miniconda3/envs/renewables-analysis/lib/python3.12/site-packages/climakitae/core/data_load.py:591: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'time' ('time',) The recommendation is to set join explicitly for this case.
#   one_scenario = xr.concat(
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!! Returned data array is huge. Operations could take 10x to infinity longer than 1GB of data !!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#   ✓ Loaded: ('scenario', 'simulation', 'time', 'y', 'x')
#   Available simulations: [np.str_('WRF_FGOALS-g3_r1i1p1f1'), np.str_('WRF_CNRM-ESM2-1_r1i1p1f2'), np.str_('WRF_CESM2_r11i1p1f1'), np.str_('WRF_EC-Earth3_r1i1p1f1'), np.str_('WRF_MPI-ESM1-2-HR_r3i1p1f1'), np.str_('WRF_TaiESM1_r1i1p1f1'), np.str_('WRF_MIROC6_r1i1p1f1'), np.str_('WRF_EC-Earth3-Veg_r1i1p1f1')]
#
# ============================================================
# Climate data loaded for 2 variables
# ============================================================

# %% [markdown]
# ## Extract Simulations and Aggregate to Regions
#
# Now extract each simulation/GWL combination and aggregate to load zones.

# %%
# Process each simulation/GWL combination
print("\nExtracting simulations and aggregating to regions...")
print("="*60)

for simulation in simulations:
    print(f"\n{simulation}:")
    
    for gwl in gwls:
        print(f"  GWL {gwl}°C:")
        
        for var_short, climate_data_all in climate_data_cache.items():
            try:
                # Extract this simulation and GWL period
                climate_data = extract_simulation_gwl_period(
                    climate_data=climate_data_all,
                    simulation=simulation,
                    gwl=gwl
                )
                
                # Aggregate to regions
                regional_data = compute_regional_climate_average(
                    climate_data=climate_data,
                    shapefile_path=shapefile_path
                )
                
                # Store
                regional_climate[simulation][gwl][var_short] = regional_data
                
                print(f"    {var_short}: ✓")
                
            except Exception as e:
                print(f"    {var_short}: ✗ Error: {e}")
                continue

print("\n" + "="*60)
print("Regional climate data processing complete!")
print("="*60)
# Out:
# Extracting simulations and aggregating to regions...
# ============================================================
#
# ec-earth3:
#   GWL 0.8°C:
#     T2m: ✓
#     rh: ✓
#   GWL 2.0°C:
#     T2m: ✓
#     rh: ✓
#
# miroc6:
#   GWL 0.8°C:
#     T2m: ✓
#     rh: ✓
#   GWL 2.0°C:
#     T2m: ✓
#     rh: ✓
#
# mpi-esm1-2-hr:
#   GWL 0.8°C:
#     T2m: ✓
#     rh: ✓
#   GWL 2.0°C:
#     T2m: ✓
#     rh: ✓
#
# taiesm1:
#   GWL 0.8°C:
#     T2m: ✓
#     rh: ✓
#   GWL 2.0°C:
#     T2m: ✓
#     rh: ✓
#
# ============================================================
# Regional climate data processing complete!
# ============================================================

# %% [markdown]
# ## Compute Anomalies (if requested)
#
# Calculate day-of-year anomalies for climate variables if configured.

# %%
# Process climate anomalies if requested
if climate_use_anomaly:
    print("Computing climate anomalies...")
    print("  Using GWL 0.8 as reference period for all warming levels")
    
    reference_gwl = 0.8
    
    for simulation in regional_climate:
        # First, save the reference period data (GWL 0.8) BEFORE computing anomalies
        reference_data_saved = {}
        for var_short in regional_climate[simulation][reference_gwl]:
            # Make a copy to preserve original data
            reference_data_saved[var_short] = regional_climate[simulation][reference_gwl][var_short].copy()
        
        # Now compute anomalies for all GWLs using the saved reference
        for gwl in regional_climate[simulation]:
            for var_short in regional_climate[simulation][gwl]:
                # Compute anomalies relative to GWL 0.8 climatology
                regional_climate[simulation][gwl][var_short] = compute_anomalies(
                    regional_climate[simulation][gwl][var_short],
                    reference_data=reference_data_saved[var_short]
                )
    
    print("Anomalies computed relative to GWL 0.8 reference period")
else:
    print("Using raw climate values (no anomalies)")
# Out:
# Computing climate anomalies...
#   Using GWL 0.8 as reference period for all warming levels
# Anomalies computed relative to GWL 0.8 reference period

# %% [markdown]
# ## Create Correlation Scatterplots
#
# Generate interactive scatterplots comparing demand vs climate variables.
#
# Each plot shows:
# - Demand (y-axis): SEI or raw peak load
# - Climate variable (x-axis): anomaly or raw value
# - Points colored by GWL
# - Separate plots for each model, region, and climate variable
#
# **Data Alignment (Critical):**
# - Uses `xr.align()` with `join='inner'` to ensure demand and climate data are matched on exact dates
# - Only includes dates present in both datasets
# - Prevents silent misalignment that could corrupt correlation analysis

# %%
def create_demand_climate_scatterplot(
    demand_data_gwl1, 
    climate_data_gwl1,
    demand_data_gwl2,
    climate_data_gwl2,
    simulation,
    region,
    climate_var_name,
    gwl1=0.8,
    gwl2=2.0,
    demand_label="Demand SEI",
    climate_label="Climate Variable",
    overlay=False
):
    """
    Create scatterplots for two GWLs (side-by-side or overlaid).
    
    Parameters
    ----------
    demand_data_gwl1 : xr.DataArray
        Demand data for first GWL
    climate_data_gwl1 : xr.DataArray
        Climate data for first GWL
    demand_data_gwl2 : xr.DataArray
        Demand data for second GWL
    climate_data_gwl2 : xr.DataArray
        Climate data for second GWL
    simulation : str
        Model name
    region : str
        Region name
    climate_var_name : str
        Climate variable name for labels
    gwl1, gwl2 : float
        Warming levels
    demand_label : str
        Label for demand axis
    climate_label : str
        Label for climate axis
    overlay : bool
        If True, overlay both GWLs on single plot. If False, side-by-side plots.
        
    Returns
    -------
    holoviews.Layout or holoviews.Overlay
        Side-by-side scatter plots or overlaid scatter plot
    """
    # Explicitly align data on time coordinates (CRITICAL for accurate correlation)
    # This ensures demand and climate are matched exactly on date
    aligned_demand_gwl1, aligned_climate_gwl1 = xr.align(
        demand_data_gwl1, 
        climate_data_gwl1, 
        join='inner'  # Only keep dates present in both datasets
    )
    
    aligned_demand_gwl2, aligned_climate_gwl2 = xr.align(
        demand_data_gwl2, 
        climate_data_gwl2, 
        join='inner'
    )
    
    # Prepare data for GWL1 - now guaranteed to be aligned
    df_gwl1 = pd.DataFrame({
        'demand': aligned_demand_gwl1.values.flatten(),
        'climate': aligned_climate_gwl1.values.flatten(),
        'time': aligned_demand_gwl1.time.values.flatten()
    })
    
    # Prepare data for GWL2
    df_gwl2 = pd.DataFrame({
        'demand': aligned_demand_gwl2.values.flatten(),
        'climate': aligned_climate_gwl2.values.flatten(),
        'time': aligned_demand_gwl2.time.values.flatten()
    })
    
    # Add GWL label to both dataframes for overlaid legend
    df_gwl1['GWL'] = f'{gwl1}°C'
    df_gwl2['GWL'] = f'{gwl2}°C'
    
    # Log alignment info for validation
    n_points_gwl1 = len(df_gwl1)
    n_points_gwl2 = len(df_gwl2)
    if n_points_gwl1 != len(demand_data_gwl1.time) or n_points_gwl2 != len(demand_data_gwl2.time):
        print(f"  Note: Alignment removed mismatched dates. GWL1: {n_points_gwl1} points, GWL2: {n_points_gwl2} points")
    
    if overlay:
        # Overlaid plot - combine data and color by GWL
        df_combined = pd.concat([df_gwl1, df_gwl2], ignore_index=True)
        
        scatter = hv.Scatter(df_combined, 'climate', ['demand', 'GWL']).opts(
            width=600, height=500, size=5, alpha=0.08, muted_alpha=1,
            color='GWL',
            cmap={f'{gwl1}°C': gwl_colors.get(gwl1, 'blue'), 
                  f'{gwl2}°C': gwl_colors.get(gwl2, 'red')},
            tools=['hover', 'box_select'],
            xlabel=climate_label,
            ylabel=demand_label,
            title=f'{region} | {simulation}\nGWL {gwl1}°C vs {gwl2}°C',
            show_legend=False,
        )


        points_legend = hv.Scatter(pd.concat([df_combined.head(10),df_combined.tail(10)]), 'climate', ['demand', 'GWL']).opts(
            size=0,                   # Invisible on plot
            alpha=1.0,                # Fully opaque for legend
            color='GWL',
            cmap={f'{gwl1}°C': gwl_colors.get(gwl1, 'blue'), 
                f'{gwl2}°C': gwl_colors.get(gwl2, 'red')},
            show_legend=True,         # This drives the legend
            legend_position='top_right'
)
        scatter = scatter * points_legend



        return scatter
    else:
        # Side-by-side plots
        scatter_gwl1 = hv.Scatter(df_gwl1, 'climate', 'demand').opts(
            width=450, height=400, size=5, alpha=0.1,
            color=gwl_colors.get(gwl1, 'blue'),
            tools=['hover', 'box_select'],
            xlabel=climate_label,
            ylabel=demand_label,
            title=f'{region} | {simulation}\nGWL {gwl1}°C'
        )
        
        scatter_gwl2 = hv.Scatter(df_gwl2, 'climate', 'demand').opts(
            width=450, height=400, size=5, alpha=0.1,
            color=gwl_colors.get(gwl2, 'red'),
            tools=['hover', 'box_select'],
            xlabel=climate_label,
            ylabel=demand_label,
            title=f'{region} | {simulation}\nGWL {gwl2}°C'
        )
        
        # Return side-by-side layout
        return (scatter_gwl1 + scatter_gwl2).opts(shared_axes=True)

# %% [markdown]
# ## Generate Plots for All Combinations
#
# Loop through all simulations, regions, and climate variables to create scatterplots.
#
# **Plot Layout Options:**
# - **Side-by-side** (`overlay_plots=False`): Shows two separate plots for easy direct comparison
# - **Overlaid** (`overlay_plots=True`): Shows both GWLs on one plot with color-coded legend for pattern comparison

# %%
# Select a subset for initial exploration
test_simulation = "taiesm1"  # Change to explore different models

# Plot configuration
overlay_plots = True  # True = overlay both GWLs on one plot, False = side-by-side

# Set labels based on configuration
if demand_data_type == "sei":
    demand_label = "Demand SEI"
elif demand_use_anomaly:
    demand_label = "Demand Anomaly (MW)"
else:
    demand_label = "Peak Demand (MW)"


climate_label_suffix = " Anomaly" if climate_use_anomaly else ""

# %%
# Example: Temperature vs Demand for EC-Earth3, PGE region
simulation = test_simulation
region = "SCE"
var_short = "T2m"
climate_var_full = "Air Temperature at 2m"

gwl1, gwl2 = gwls[0], gwls[1]

print(f"\nPlotting {var_short} vs Demand")
print(f"  Simulation: {simulation}")
print(f"  Region: {region}")
print(f"  GWLs: {gwl1}°C, {gwl2}°C")

# Get demand data for this region and GWLs
if demand_data_type == "sei":
    # Get the time periods for GWL filtering
    wrf_sim_name = sim_name_dict[simulation]
    model = wrf_sim_name.split("_")[1]
    ensemble_member = wrf_sim_name.split("_")[2]
    
    start_year_1, end_year_1 = get_gwl_crossing_period(model, ensemble_member, gwl1)
    start_year_2, end_year_2 = get_gwl_crossing_period(model, ensemble_member, gwl2)
    
    # Select region
    demand_gwl1 = demand_data[simulation].sel(region=region)
    demand_gwl2 = demand_data[simulation].sel(region=region)
    
    # Check if data has 'year' and 'dayofyear' dimensions or just 'time'
    if 'year' in demand_gwl1.dims and 'dayofyear' in demand_gwl1.dims:
        # SEI data with year/dayofyear structure
        demand_gwl1 = demand_gwl1.sel(year=slice(start_year_1, end_year_1))
        demand_gwl2 = demand_gwl2.sel(year=slice(start_year_2, end_year_2))
        
        # Stack back to time dimension for plotting
        demand_gwl1_stacked = demand_gwl1.stack(time=['year', 'dayofyear']).reset_index('time')
        demand_gwl2_stacked = demand_gwl2.stack(time=['year', 'dayofyear']).reset_index('time')
    else:
        # SEI data with regular time dimension
        demand_gwl1_stacked = demand_gwl1.sel(
            time=slice(f"{start_year_1}-01-01", f"{end_year_1}-12-31")
        )
        demand_gwl2_stacked = demand_gwl2.sel(
            time=slice(f"{start_year_2}-01-01", f"{end_year_2}-12-31")
        )
    
else:
    # Raw peak load
    demand_gwl1 = load_demand_peak_load(simulation, gwl=gwl1).sel(region=region)
    demand_gwl2 = load_demand_peak_load(simulation, gwl=gwl2).sel(region=region)
    
    if demand_use_anomaly:
        demand_gwl1 = compute_anomalies(demand_gwl1)
        demand_gwl2 = compute_anomalies(demand_gwl2)
    
    demand_gwl1_stacked = demand_gwl1
    demand_gwl2_stacked = demand_gwl2

# Get climate data
climate_gwl1 = regional_climate[simulation][gwl1][var_short].sel(region=region)
climate_gwl2 = regional_climate[simulation][gwl2][var_short].sel(region=region)

# Create plot
plot = create_demand_climate_scatterplot(
    demand_gwl1_stacked,
    climate_gwl1,
    demand_gwl2_stacked,
    climate_gwl2,
    simulation=simulation,
    region=region,
    climate_var_name=climate_var_full,
    gwl1=gwl1,
    gwl2=gwl2,
    demand_label=demand_label,
    climate_label=climate_var_full + climate_label_suffix,
    overlay=overlay_plots
)
filename = f"{simulation}_{region}_{var_short}_vs_demand_{demand_data_type}.html"
filepath = output_dir / filename
hv.save(plot, filepath)
plot
# Out:
# Plotting T2m vs Demand
#   Simulation: taiesm1
#   Region: SCE
#   GWLs: 0.8°C, 2.0°C
# :Overlay
#    .Scatter.I  :Scatter   [climate]   (demand,GWL)
#    .Scatter.II :Scatter   [climate]   (demand,GWL)

# %% [markdown]
# ## Loop Through All Combinations
#
# Generate and optionally save plots for all models, regions, and climate variables.

# %%
# Configuration for batch processing
save_plots = True  # Set to True to save plots
show_plots = False   # Set to False to suppress display (faster when saving many plots)

# Process all combinations
for simulation in simulations:
    print(f"\n{'='*60}")
    print(f"Simulation: {simulation}")
    print(f"{'='*60}")
    
    if simulation not in demand_data or simulation not in regional_climate:
        print(f"  Skipping {simulation} - data not available")
        continue
    
    # Get regions from demand data
    regions = demand_data[simulation].region.values
    
    for region in regions:
        print(f"\n  Region: {region}")
        
        for climate_var_full, var_short in climate_variables.items():
            print(f"    {climate_var_full}...", end=" ")
            
            try:
                gwl1, gwl2 = gwls[0], gwls[1]
                
                # Prepare demand data
                if demand_data_type == "sei":
                    # Get GWL periods
                    wrf_sim_name = sim_name_dict[simulation]
                    model = wrf_sim_name.split("_")[1]
                    ensemble_member = wrf_sim_name.split("_")[2]
                    
                    start_year_1, end_year_1 = get_gwl_crossing_period(model, ensemble_member, gwl1)
                    start_year_2, end_year_2 = get_gwl_crossing_period(model, ensemble_member, gwl2)
                    
                    # Select region
                    demand_gwl1 = demand_data[simulation].sel(region=region)
                    demand_gwl2 = demand_data[simulation].sel(region=region)
                    
                    # Check dimensions and filter appropriately
                    if 'year' in demand_gwl1.dims and 'dayofyear' in demand_gwl1.dims:
                        # SEI with year/dayofyear structure
                        demand_gwl1 = demand_gwl1.sel(year=slice(start_year_1, end_year_1))
                        demand_gwl2 = demand_gwl2.sel(year=slice(start_year_2, end_year_2))
                        
                        # Stack to time
                        demand_gwl1_stacked = demand_gwl1.stack(time=['year', 'dayofyear']).reset_index('time')
                        demand_gwl2_stacked = demand_gwl2.stack(time=['year', 'dayofyear']).reset_index('time')
                    else:
                        # SEI with regular time dimension
                        demand_gwl1_stacked = demand_gwl1.sel(
                            time=slice(f"{start_year_1}-01-01", f"{end_year_1}-12-31")
                        )
                        demand_gwl2_stacked = demand_gwl2.sel(
                            time=slice(f"{start_year_2}-01-01", f"{end_year_2}-12-31")
                        )
                else:
                    demand_gwl1 = load_demand_peak_load(simulation, gwl=gwl1).sel(region=region)
                    demand_gwl2 = load_demand_peak_load(simulation, gwl=gwl2).sel(region=region)
                    
                    if demand_use_anomaly:
                        demand_gwl1 = compute_anomalies(demand_gwl1)
                        demand_gwl2 = compute_anomalies(demand_gwl2)
                    
                    demand_gwl1_stacked = demand_gwl1
                    demand_gwl2_stacked = demand_gwl2
                
                # Get climate data
                climate_gwl1 = regional_climate[simulation][gwl1][var_short].sel(region=region)
                climate_gwl2 = regional_climate[simulation][gwl2][var_short].sel(region=region)
                
                # Create plot
                plot = create_demand_climate_scatterplot(
                    demand_gwl1_stacked,
                    climate_gwl1,
                    demand_gwl2_stacked,
                    climate_gwl2,
                    simulation=simulation,
                    region=region,
                    climate_var_name=climate_var_full,
                    gwl1=gwl1,
                    gwl2=gwl2,
                    demand_label=demand_label,
                    climate_label=climate_var_full + climate_label_suffix,
                    overlay=overlay_plots
                )
                
                if save_plots:
                    # Save as HTML for interactivity
                    filename = f"{simulation}_{region}_{var_short}_vs_demand.html"
                    filepath = output_dir / filename
                    hv.save(plot, filepath)
                    print(f"✓ Saved to {filename}")
                else:
                    print("✓")
                
                if show_plots:
                    display(plot)
                    
            except Exception as e:
                print(f"✗ Error: {e}")
                continue

print("\n" + "="*60)
print("Batch processing complete!")
if save_plots:
    print(f"Plots saved to: {output_dir}")
print("="*60)
# Out:
# ============================================================
# Simulation: ec-earth3
# ============================================================
#
#   Region: SCE
#     Air Temperature at 2m... ✓ Saved to ec-earth3_SCE_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to ec-earth3_SCE_rh_vs_demand.html
#
#   Region: IID
#     Air Temperature at 2m... ✓ Saved to ec-earth3_IID_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to ec-earth3_IID_rh_vs_demand.html
#
#   Region: NCNC
#     Air Temperature at 2m... ✓ Saved to ec-earth3_NCNC_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to ec-earth3_NCNC_rh_vs_demand.html
#
#   Region: LDWP
#     Air Temperature at 2m... ✓ Saved to ec-earth3_LDWP_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to ec-earth3_LDWP_rh_vs_demand.html
#
#   Region: WECC-MTN
#     Air Temperature at 2m... ✓ Saved to ec-earth3_WECC-MTN_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to ec-earth3_WECC-MTN_rh_vs_demand.html
#
#   Region: WECC-SW
#     Air Temperature at 2m... ✓ Saved to ec-earth3_WECC-SW_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to ec-earth3_WECC-SW_rh_vs_demand.html
#
#   Region: PGE
#     Air Temperature at 2m... ✓ Saved to ec-earth3_PGE_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to ec-earth3_PGE_rh_vs_demand.html
#
#   Region: SDGE
#     Air Temperature at 2m... ✓ Saved to ec-earth3_SDGE_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to ec-earth3_SDGE_rh_vs_demand.html
#
#   Region: WECC-NW
#     Air Temperature at 2m... ✓ Saved to ec-earth3_WECC-NW_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to ec-earth3_WECC-NW_rh_vs_demand.html
#
# ============================================================
# Simulation: miroc6
# ============================================================
#
#   Region: SCE
#     Air Temperature at 2m... ✓ Saved to miroc6_SCE_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to miroc6_SCE_rh_vs_demand.html
#
#   Region: IID
#     Air Temperature at 2m... ✓ Saved to miroc6_IID_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to miroc6_IID_rh_vs_demand.html
#
#   Region: NCNC
#     Air Temperature at 2m... ✓ Saved to miroc6_NCNC_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to miroc6_NCNC_rh_vs_demand.html
#
#   Region: LDWP
#     Air Temperature at 2m... ✓ Saved to miroc6_LDWP_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to miroc6_LDWP_rh_vs_demand.html
#
#   Region: WECC-MTN
#     Air Temperature at 2m... ✓ Saved to miroc6_WECC-MTN_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to miroc6_WECC-MTN_rh_vs_demand.html
#
#   Region: WECC-SW
#     Air Temperature at 2m... ✓ Saved to miroc6_WECC-SW_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to miroc6_WECC-SW_rh_vs_demand.html
#
#   Region: PGE
#     Air Temperature at 2m... ✓ Saved to miroc6_PGE_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to miroc6_PGE_rh_vs_demand.html
#
#   Region: SDGE
#     Air Temperature at 2m... ✓ Saved to miroc6_SDGE_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to miroc6_SDGE_rh_vs_demand.html
#
#   Region: WECC-NW
#     Air Temperature at 2m... ✓ Saved to miroc6_WECC-NW_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to miroc6_WECC-NW_rh_vs_demand.html
#
# ============================================================
# Simulation: mpi-esm1-2-hr
# ============================================================
#
#   Region: SCE
#     Air Temperature at 2m... ✓ Saved to mpi-esm1-2-hr_SCE_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to mpi-esm1-2-hr_SCE_rh_vs_demand.html
#
#   Region: IID
#     Air Temperature at 2m... ✓ Saved to mpi-esm1-2-hr_IID_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to mpi-esm1-2-hr_IID_rh_vs_demand.html
#
#   Region: NCNC
#     Air Temperature at 2m... ✓ Saved to mpi-esm1-2-hr_NCNC_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to mpi-esm1-2-hr_NCNC_rh_vs_demand.html
#
#   Region: LDWP
#     Air Temperature at 2m... ✓ Saved to mpi-esm1-2-hr_LDWP_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to mpi-esm1-2-hr_LDWP_rh_vs_demand.html
#
#   Region: WECC-MTN
#     Air Temperature at 2m... ✓ Saved to mpi-esm1-2-hr_WECC-MTN_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to mpi-esm1-2-hr_WECC-MTN_rh_vs_demand.html
#
#   Region: WECC-SW
#     Air Temperature at 2m... ✓ Saved to mpi-esm1-2-hr_WECC-SW_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to mpi-esm1-2-hr_WECC-SW_rh_vs_demand.html
#
#   Region: PGE
#     Air Temperature at 2m... ✓ Saved to mpi-esm1-2-hr_PGE_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to mpi-esm1-2-hr_PGE_rh_vs_demand.html
#
#   Region: SDGE
#     Air Temperature at 2m... ✓ Saved to mpi-esm1-2-hr_SDGE_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to mpi-esm1-2-hr_SDGE_rh_vs_demand.html
#
#   Region: WECC-NW
#     Air Temperature at 2m... ✓ Saved to mpi-esm1-2-hr_WECC-NW_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to mpi-esm1-2-hr_WECC-NW_rh_vs_demand.html
#
# ============================================================
# Simulation: taiesm1
# ============================================================
#
#   Region: SCE
#     Air Temperature at 2m... ✓ Saved to taiesm1_SCE_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to taiesm1_SCE_rh_vs_demand.html
#
#   Region: IID
#     Air Temperature at 2m... ✓ Saved to taiesm1_IID_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to taiesm1_IID_rh_vs_demand.html
#
#   Region: NCNC
#     Air Temperature at 2m... ✓ Saved to taiesm1_NCNC_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to taiesm1_NCNC_rh_vs_demand.html
#
#   Region: LDWP
#     Air Temperature at 2m... ✓ Saved to taiesm1_LDWP_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to taiesm1_LDWP_rh_vs_demand.html
#
#   Region: WECC-MTN
#     Air Temperature at 2m... ✓ Saved to taiesm1_WECC-MTN_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to taiesm1_WECC-MTN_rh_vs_demand.html
#
#   Region: WECC-SW
#     Air Temperature at 2m... ✓ Saved to taiesm1_WECC-SW_T2m_vs_demand.html
#     Relative humidity... ✗ Error: Read timeout on endpoint URL: "https://cadcat.s3.amazonaws.com/wrf/ucla/taiesm1/historical/day/rh/d02/rh/0.0.4"
#
#   Region: PGE
#     Air Temperature at 2m... ✗ Error: Read timeout on endpoint URL: "https://cadcat.s3.amazonaws.com/wrf/ucla/taiesm1/ssp370/day/t2/d02/t2/0.2.2"
#     Relative humidity... ✓ Saved to taiesm1_PGE_rh_vs_demand.html
#
#   Region: SDGE
#     Air Temperature at 2m... ✓ Saved to taiesm1_SDGE_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to taiesm1_SDGE_rh_vs_demand.html
#
#   Region: WECC-NW
#     Air Temperature at 2m... ✓ Saved to taiesm1_WECC-NW_T2m_vs_demand.html
#     Relative humidity... ✓ Saved to taiesm1_WECC-NW_rh_vs_demand.html
#
# ============================================================
# Batch processing complete!
# Plots saved to: figures/climate_drivers_of_demand
# ============================================================

# %% [markdown]
# ## Correlation Statistics
#
# Calculate correlation coefficients between demand and climate variables.

# %%
# Calculate correlations for all combinations
correlation_results = []

for simulation in simulations:
    if simulation not in demand_data or simulation not in regional_climate:
        continue
    
    regions = demand_data[simulation].region.values
    
    for region in regions:
        for gwl in gwls:
            for climate_var_full, var_short in climate_variables.items():
                try:
                    # Prepare demand data
                    if demand_data_type == "sei":
                        demand = demand_data[simulation].sel(region=region)
                        
                        # Filter by GWL period
                        wrf_sim_name = sim_name_dict[simulation]
                        model = wrf_sim_name.split("_")[1]
                        ensemble_member = wrf_sim_name.split("_")[2]
                        start_year, end_year = get_gwl_crossing_period(model, ensemble_member, gwl)
                        
                        # Check dimensions and filter appropriately
                        if 'year' in demand.dims and 'dayofyear' in demand.dims:
                            # SEI with year/dayofyear structure
                            demand = demand.sel(year=slice(start_year, end_year))
                            demand_stacked = demand.stack(time=['year', 'dayofyear']).reset_index('time')
                        else:
                            # SEI with regular time dimension
                            demand_stacked = demand.sel(
                                time=slice(f"{start_year}-01-01", f"{end_year}-12-31")
                            )
                    else:
                        demand = load_demand_peak_load(simulation, gwl=gwl).sel(region=region)
                        if demand_use_anomaly:
                            demand = compute_anomalies(demand)
                        demand_stacked = demand
                    
                    # Get climate data
                    climate = regional_climate[simulation][gwl][var_short].sel(region=region)
                    
                    # CRITICAL: Explicitly align on time coordinate before correlation
                    aligned_demand, aligned_climate = xr.align(
                        demand_stacked,
                        climate,
                        join='inner'  # Only dates present in both
                    )
                    
                    # Extract values from aligned data
                    demand_vals = aligned_demand.values.flatten()
                    climate_vals = aligned_climate.values.flatten()
                    
                    # Remove NaNs
                    mask = ~(np.isnan(demand_vals) | np.isnan(climate_vals))
                    demand_vals = demand_vals[mask]
                    climate_vals = climate_vals[mask]
                    
                    # Calculate correlation
                    if len(demand_vals) > 0:
                        corr = np.corrcoef(demand_vals, climate_vals)[0, 1]
                        
                        correlation_results.append({
                            'simulation': simulation,
                            'region': region,
                            'gwl': gwl,
                            'climate_var': climate_var_full,
                            'correlation': corr,
                            'n_points': len(demand_vals)
                        })
                
                except Exception as e:
                    continue

# Convert to DataFrame
corr_df = pd.DataFrame(correlation_results)
print(f"Calculated {len(corr_df)} correlations")
corr_df.head(20)
# Out:
# Calculated 134 correlations
#    simulation    region  gwl            climate_var  correlation  n_points
# 0   ec-earth3       SCE  0.8  Air Temperature at 2m     0.474708      9483
# 1   ec-earth3       SCE  0.8      Relative humidity    -0.270950      9483
# 2   ec-earth3       SCE  2.0  Air Temperature at 2m     0.509732      8025
# 3   ec-earth3       SCE  2.0      Relative humidity    -0.311246      8025
# 4   ec-earth3       IID  0.8  Air Temperature at 2m     0.375262      9483
# 5   ec-earth3       IID  0.8      Relative humidity    -0.173074      9483
# 6   ec-earth3      NCNC  0.8  Air Temperature at 2m     0.237122      9483
# 7   ec-earth3      NCNC  0.8      Relative humidity    -0.372170      9483
# 8   ec-earth3      NCNC  2.0  Air Temperature at 2m     0.355985      8025
# 9   ec-earth3      NCNC  2.0      Relative humidity    -0.378557      8025
# 10  ec-earth3      LDWP  0.8  Air Temperature at 2m     0.406788      9483
# 11  ec-earth3      LDWP  0.8      Relative humidity    -0.160616      9483
# 12  ec-earth3      LDWP  2.0  Air Temperature at 2m     0.426857      8025
# 13  ec-earth3      LDWP  2.0      Relative humidity    -0.233009      8025
# 14  ec-earth3  WECC-MTN  0.8  Air Temperature at 2m    -0.191512      9483
# 15  ec-earth3  WECC-MTN  0.8      Relative humidity    -0.225694      9483
# 16  ec-earth3  WECC-MTN  2.0  Air Temperature at 2m    -0.031582      8025
# 17  ec-earth3  WECC-MTN  2.0      Relative humidity    -0.211567      8025
# 18  ec-earth3       PGE  0.8  Air Temperature at 2m     0.352525      9483
# 19  ec-earth3       PGE  0.8      Relative humidity    -0.399380      9483

# %%
# Summary statistics by climate variable and GWL
if len(corr_df) > 0:
    summary = corr_df.groupby(['climate_var', 'gwl'])['correlation'].agg(['mean', 'std', 'min', 'max'])
    print("\nCorrelation Summary:")
    print(summary)
# Out:
# Correlation Summary:
#                                mean       std       min       max
# climate_var           gwl
# Air Temperature at 2m 0.8  0.244848  0.279972 -0.265467  0.587441
#                       2.0  0.324766  0.262974 -0.161632  0.702872
# Relative humidity     0.8 -0.323059  0.087272 -0.444218 -0.153427
#                       2.0 -0.359605  0.092530 -0.579509 -0.211567
